# %% [markdown]
# ## Working with Scikit-learn neural network classifier architectures (Multi-layer Perceptron) for predicting broken pipes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.neural_network import MLPClassifier
from crossval import crossval_by_year

# %%
df = pd.read_csv('final_data.csv')

# %%
params = {
    'learning_rate_init': 0.001,
    'alpha': 0,
    'random_state': 42,
    'hidden_layer_sizes': (75, 50, 25),
    'verbose': True,
    'max_iter': 50
}

avg_acc = crossval_by_year(df, MLPClassifier, params, normalize_data=True)
# Out:
# Iteration 1, loss = 0.03018689
# Iteration 2, loss = 0.01982299
# Iteration 3, loss = 0.01707304
# Iteration 4, loss = 0.01637276
# Iteration 5, loss = 0.01591527
# Iteration 6, loss = 0.01556887
# Iteration 7, loss = 0.01515773
# Iteration 8, loss = 0.01491617
# Iteration 9, loss = 0.01464138
# Iteration 10, loss = 0.01440449
# Iteration 11, loss = 0.01419073
# Iteration 12, loss = 0.01390835
# Iteration 13, loss = 0.01375485
# Iteration 14, loss = 0.01373956
# Iteration 15, loss = 0.01331410
# Iteration 16, loss = 0.01318585
# Iteration 17, loss = 0.01306397
# Iteration 18, loss = 0.01294089
# Iteration 19, loss = 0.01279189
# Iteration 20, loss = 0.01274072
# Iteration 21, loss = 0.01241735
# Iteration 22, loss = 0.01239345
# Iteration 23, loss = 0.01226973
# Iteration 24, loss = 0.01221382
# Iteration 25, loss = 0.01194731
# Iteration 26, loss = 0.01194585
# Iteration 27, loss = 0.01175682
# Iteration 28, loss = 0.01166544
# Iteration 29, loss = 0.01163681
# ...

# %%
params = {
    'learning_rate_init': 0.001,
    'alpha': 0,
    'random_state': 42,
    'hidden_layer_sizes': (100, 75, 25),
    'verbose': True,
    'max_iter': 50
}

avg_acc = crossval_by_year(df, MLPClassifier, params, normalize_data=True)
# Out:
# Iteration 1, loss = 0.03054763
# Iteration 2, loss = 0.01943414
# Iteration 3, loss = 0.01715599
# Iteration 4, loss = 0.01645432
# Iteration 5, loss = 0.01590743
# Iteration 6, loss = 0.01560123
# Iteration 7, loss = 0.01510505
# Iteration 8, loss = 0.01473062
# Iteration 9, loss = 0.01443654
# Iteration 10, loss = 0.01427473
# Iteration 11, loss = 0.01392408
# Iteration 12, loss = 0.01372065
# Iteration 13, loss = 0.01341982
# Iteration 14, loss = 0.01341338
# Iteration 15, loss = 0.01307069
# Iteration 16, loss = 0.01293240
# Iteration 17, loss = 0.01276816
# Iteration 18, loss = 0.01256925
# Iteration 19, loss = 0.01237874
# Iteration 20, loss = 0.01230703
# Iteration 21, loss = 0.01203019
# Iteration 22, loss = 0.01187611
# Iteration 23, loss = 0.01182024
# Iteration 24, loss = 0.01165777
# Iteration 25, loss = 0.01163194
# Iteration 26, loss = 0.01145904
# Iteration 27, loss = 0.01131747
# Iteration 28, loss = 0.01139453
# Iteration 29, loss = 0.01128833
# ...

# %%
params = {
    'learning_rate_init': 0.001,
    'alpha': 0.00001,
    'random_state': 42,
    'hidden_layer_sizes': (75, 50, 25),
    'verbose': True,
    'max_iter': 50
}

avg_acc = crossval_by_year(df, MLPClassifier, params, normalize_data=True)
# Out:
# Iteration 1, loss = 0.03017838
# Iteration 2, loss = 0.01968111
# Iteration 3, loss = 0.01701888
# Iteration 4, loss = 0.01636928
# Iteration 5, loss = 0.01590296
# Iteration 6, loss = 0.01547848
# Iteration 7, loss = 0.01503676
# Iteration 8, loss = 0.01476177
# Iteration 9, loss = 0.01452586
# Iteration 10, loss = 0.01415673
# Iteration 11, loss = 0.01393361
# Iteration 12, loss = 0.01367084
# Iteration 13, loss = 0.01353829
# Iteration 14, loss = 0.01334735
# Iteration 15, loss = 0.01314865
# Iteration 16, loss = 0.01290175
# Iteration 17, loss = 0.01277638
# Iteration 18, loss = 0.01269221
# Iteration 19, loss = 0.01257933
# Iteration 20, loss = 0.01230596
# Iteration 21, loss = 0.01224736
# Iteration 22, loss = 0.01207132
# Iteration 23, loss = 0.01201339
# Iteration 24, loss = 0.01200990
# Iteration 25, loss = 0.01179415
# Iteration 26, loss = 0.01178158
# Iteration 27, loss = 0.01159477
# Iteration 28, loss = 0.01153603
# Iteration 29, loss = 0.01142125
# ...

# %%
# best configuration so far
params = {
    'learning_rate_init': 0.001,
    'alpha': 0.0001,
    'random_state': 42,
    'hidden_layer_sizes': (75, 50, 25),
    'verbose': True,
    'max_iter': 50
}

avg_acc = crossval_by_year(df, MLPClassifier, params, normalize_data=True)
# Out:
# Iteration 1, loss = 0.03020603
# Iteration 2, loss = 0.01969402
# Iteration 3, loss = 0.01712568
# Iteration 4, loss = 0.01646665
# Iteration 5, loss = 0.01600759
# Iteration 6, loss = 0.01557974
# Iteration 7, loss = 0.01524592
# Iteration 8, loss = 0.01495231
# Iteration 9, loss = 0.01470084
# Iteration 10, loss = 0.01448215
# Iteration 11, loss = 0.01422346
# Iteration 12, loss = 0.01403104
# Iteration 13, loss = 0.01386796
# Iteration 14, loss = 0.01371113
# Iteration 15, loss = 0.01347367
# Iteration 16, loss = 0.01336680
# Iteration 17, loss = 0.01305516
# Iteration 18, loss = 0.01301922
# Iteration 19, loss = 0.01274536
# Iteration 20, loss = 0.01267329
# Iteration 21, loss = 0.01250812
# Iteration 22, loss = 0.01237063
# Iteration 23, loss = 0.01229054
# Iteration 24, loss = 0.01218488
# Iteration 25, loss = 0.01198099
# Iteration 26, loss = 0.01184655
# Iteration 27, loss = 0.01188452
# Iteration 28, loss = 0.01172639
# Iteration 29, loss = 0.01174325
# ...

# %%
params = {
    'learning_rate_init': 0.001,
    'alpha': 0.001,
    'random_state': 42,
    'hidden_layer_sizes': (75, 50, 25),
    'verbose': True,
    'max_iter': 50
}

avg_acc = crossval_by_year(df, MLPClassifier, params, normalize_data=True)
# Out:
# Iteration 1, loss = 0.03056659
# Iteration 2, loss = 0.02000752
# Iteration 3, loss = 0.01753832
# Iteration 4, loss = 0.01686086
# Iteration 5, loss = 0.01643868
# Iteration 6, loss = 0.01614528
# Iteration 7, loss = 0.01579489
# Iteration 8, loss = 0.01560565
# Iteration 9, loss = 0.01536497
# Iteration 10, loss = 0.01521320
# Iteration 11, loss = 0.01499765
# Iteration 12, loss = 0.01479463
# Iteration 13, loss = 0.01465076
# Iteration 14, loss = 0.01446146
# Iteration 15, loss = 0.01434906
# Iteration 16, loss = 0.01417087
# Iteration 17, loss = 0.01407081
# Iteration 18, loss = 0.01402391
# Iteration 19, loss = 0.01385567
# Iteration 20, loss = 0.01377644
# Iteration 21, loss = 0.01360814
# Iteration 22, loss = 0.01360874
# Iteration 23, loss = 0.01349354
# Iteration 24, loss = 0.01340895
# Iteration 25, loss = 0.01330386
# Iteration 26, loss = 0.01326152
# Iteration 27, loss = 0.01326658
# Iteration 28, loss = 0.01306358
# Iteration 29, loss = 0.01309017
# ...

# %%
params = {
    'learning_rate_init': 0.001,
    'alpha': 0.01,
    'random_state': 42,
    'hidden_layer_sizes': (75, 50, 25),
    'verbose': True,
    'max_iter': 50
}

avg_acc = crossval_by_year(df, MLPClassifier, params, normalize_data=True)
# Out:
# Iteration 1, loss = 0.03319677
# Iteration 2, loss = 0.02197925
# Iteration 3, loss = 0.01911224
# Iteration 4, loss = 0.01839083
# Iteration 5, loss = 0.01802946
# Iteration 6, loss = 0.01785624
# Iteration 7, loss = 0.01759352
# Iteration 8, loss = 0.01749216
# Iteration 9, loss = 0.01741484
# Iteration 10, loss = 0.01732366
# Iteration 11, loss = 0.01722401
# Iteration 12, loss = 0.01708101
# Iteration 13, loss = 0.01711062
# Iteration 14, loss = 0.01698466
# Iteration 15, loss = 0.01687456
# Iteration 16, loss = 0.01691601
# Iteration 17, loss = 0.01683494
# Iteration 18, loss = 0.01684553
# Iteration 19, loss = 0.01681880
# Iteration 20, loss = 0.01680531
# Iteration 21, loss = 0.01671921
# Iteration 22, loss = 0.01677090
# Iteration 23, loss = 0.01673163
# Iteration 24, loss = 0.01678891
# Iteration 25, loss = 0.01666223
# Iteration 26, loss = 0.01668977
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# ...

# %%
params = {
    'learning_rate_init': 0.001,
    'alpha': 0,
    'random_state': 42,
    'hidden_layer_sizes': (64, 128, 64, 16),
    'verbose': True,
    'max_iter': 75,
}

avg_acc = crossval_by_year(df, MLPClassifier, params, normalize_data=True)
# Out:
# Iteration 1, loss = 0.02588252
# Iteration 2, loss = 0.01856005
# Iteration 3, loss = 0.01703242
# Iteration 4, loss = 0.01625253
# Iteration 5, loss = 0.01585805
# Iteration 6, loss = 0.01547271
# Iteration 7, loss = 0.01511438
# Iteration 8, loss = 0.01476366
# Iteration 9, loss = 0.01442086
# Iteration 10, loss = 0.01414260
# Iteration 11, loss = 0.01380969
# Iteration 12, loss = 0.01360521
# Iteration 13, loss = 0.01347355
# Iteration 14, loss = 0.01323623
# Iteration 15, loss = 0.01299537
# Iteration 16, loss = 0.01282634
# Iteration 17, loss = 0.01253461
# Iteration 18, loss = 0.01250618
# Iteration 19, loss = 0.01237198
# Iteration 20, loss = 0.01216298
# Iteration 21, loss = 0.01204686
# Iteration 22, loss = 0.01185769
# Iteration 23, loss = 0.01183589
# Iteration 24, loss = 0.01167890
# Iteration 25, loss = 0.01148862
# Iteration 26, loss = 0.01125597
# Iteration 27, loss = 0.01109483
# Iteration 28, loss = 0.01106763
# Iteration 29, loss = 0.01088758
# ...

# %%
params = {
    'learning_rate_init': 0.001,
    'alpha': 0.0001,
    'random_state': 42,
    'hidden_layer_sizes': (64, 128, 64, 16),
    'verbose': True,
    'max_iter': 75,
}

avg_acc = crossval_by_year(df, MLPClassifier, params, normalize_data=True)
# Out:
# Iteration 1, loss = 0.02584503
# Iteration 2, loss = 0.01844376
# Iteration 3, loss = 0.01704837
# Iteration 4, loss = 0.01629592
# Iteration 5, loss = 0.01596031
# Iteration 6, loss = 0.01548127
# Iteration 7, loss = 0.01515582
# Iteration 8, loss = 0.01483696
# Iteration 9, loss = 0.01449339
# Iteration 10, loss = 0.01421330
# Iteration 11, loss = 0.01388461
# Iteration 12, loss = 0.01376564
# Iteration 13, loss = 0.01348059
# Iteration 14, loss = 0.01331552
# Iteration 15, loss = 0.01315173
# Iteration 16, loss = 0.01289081
# Iteration 17, loss = 0.01263385
# Iteration 18, loss = 0.01261719
# Iteration 19, loss = 0.01231861
# Iteration 20, loss = 0.01229935
# Iteration 21, loss = 0.01202020
# Iteration 22, loss = 0.01196373
# Iteration 23, loss = 0.01177614
# Iteration 24, loss = 0.01173703
# Iteration 25, loss = 0.01157029
# Iteration 26, loss = 0.01140831
# Iteration 27, loss = 0.01129974
# Iteration 28, loss = 0.01111830
# Iteration 29, loss = 0.01111978
# ...
